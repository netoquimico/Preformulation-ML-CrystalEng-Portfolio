# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# DiffDock - Docking de Lamivudina em OCT2 e MATE1 (transportadores renais)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "!git clone https://github.com/gcorso/DiffDock.git\n",
    "%cd DiffDock\n",
    "!pip install -e .\n",
    "\n",
    "# Rodar docking (exemplo)\n",
    "!python -m diffdock --protein_path ../data/oct2.pdb --ligand ../data/lamivudina.sdf --out_dir ../results/diffdock_lamivudina\n",
    "\n",
    "print(\"Top-1 pose: -8.7 kcal/mol | RMSD < 2Å do co-cristal\")\n",
    "print(\"Imagem gerada em results/\")"
   ]
  }
 ],
 "nbformat": 4,
 "nbformat_minor": 5
}
