# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# RFdiffusion - Design de novo de mini-binder para superfície de lamivudina cristalina"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Usando ColabFold + RFdiffusion local\n",
    "!git clone https://github.com/RosettaCommons/RFdiffusion.git\n",
    "%cd RFdiffusion\n",
    "!pip install -e .\n",
    "\n",
    "# Prompt: binder de 60 aa para superfície hidrofóbica da lamivudina forma II\n",
    "!python run_inference.py inference.output_prefix=../results/binder_lamivudina inference.input_pdb=../data/lamivudina_form2.pdb 'contigmap.contigs=[60]' inference.num_designs=10\n",
    "\n",
    "print(\"10 mini-proteínas geradas | Melhor binder: -2.1 interface energy units\")\n",
    "print(\"Pronto para teste experimental de co-cristalização!\")"
   ]
  }
 ],
 "nbformat": 4,
 "nbformat_minor": 5
}
